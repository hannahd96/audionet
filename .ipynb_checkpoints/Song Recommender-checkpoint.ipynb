# %%
import pandas as pd

# %%
triplets_file = 'https://static.turi.com/datasets/millionsong/10000.txt'
songs_metadata_file = 'song_data.csv'
# songs_metadata_file = 'https://static.turi.com/datasets/millionsong/song_data.csv'

# %%
song_df_1 = pd.read_table(triplets_file,header=None)
song_df_1.columns = ['user_id', 'song_id', 'listen_count']

# %%
song_df_1.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1

# %%
song_df_2 =  pd.read_csv(songs_metadata_file)
song_df = pd.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on="song_id", how="left")

# %%
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
song_df['song'] = song_df["artist_name"] + ' - ' + song_df["title"]

# %%
song_grouped = song_df.groupby(['song']).agg({'listen_count': 'count'}).reset_index()
grouped_sum = song_grouped['listen_count'].sum()
song_grouped['percentage']  = song_grouped['listen_count'].div(grouped_sum)*30
song_grouped.sort_values(['listen_count', 'song'], ascending = [0,1])
# Out:
#                                                    song  listen_count  \
# 3812                           Harmonia - Sehr kosmisch          8277
# 1112                                       Björk - Undo          7032
# 3288  Florence + The Machine - Dog Days Are Over (Ra...          6949
# 2724                     Dwight Yoakam - You're The One          6412
# 4911                            Kings Of Leon - Revelry          6145
# 6473                              OneRepublic - Secrets          5841
# 825   Barry Tuckwell/Academy of St Martin-in-the-Fie...          5385
# 1814                     Charttraxx Karaoke - Fireflies          4795
# 9413                           Train - Hey_ Soul Sister          4758
# 1726                                 Cartola - Tive Sim          4548
# 4916                       Kings Of Leon - Use Somebody          3976
# 9566                    Usher featuring will.i.am - OMG          3947
# 5157                Lil Wayne / Eminem - Drop The World          3879
# 9419                                   Train - Marry Me          3578
# 3219                          Five Iron Frenzy - Canada          3526
# 5272  Lonnie Gordon - Catch You Baby (Steve Pitron &...          3511
# 1993                           Coldplay - The Scientist          3372
# 4850  Kid Cudi / MGMT / Ratatat - Pursuit Of Happine...          3218
# 1960                                  Coldplay - Clocks          3139
# 397             Alliance Ethnik - Sincerité Et Jalousie          3129
# 9445  Travie McCoy - Billionaire [feat. Bruno Mars] ...          3113
# 396                        Alliance Ethnik - Représente          3080
# 5043             Lady GaGa / Colby O'Donis - Just Dance          3048
# 5033                              Lady GaGa - Alejandro          3032
# 5019                              La Roux - Bulletproof          3009
# 4262  Jason Mraz & Colbie Caillat - Lucky (Album Ver...          2976
# 9467                                 Tub Ring - Invalid          2887
# 7496                       Sam Cooke - Ain't Misbehavin          2866
# 6980                       Radiohead - Creep (Explicit)          2839
# 2005                                  Coldplay - Yellow          2829
# ...                                                 ...           ...
# 3166                     Feargal Sharkey - A Good Heart            56
# 4080                     Iron Maiden - Dream Of Mirrors            56
# 4178       Jack's Mannequin - I'm Ready (Album Version)            56
# 8467                       The Clash - City Of The Dead            56
# 9285                       Three Days Grace - Overrated            56
# 9343                           Tokio Hotel - Totgeliebt            56
# 65                         4 Skins - Clockwork Skinhead            55
# 2987                       Eric Church - Young And Wild            55
# 5962                          Modest Mouse - Dance Hall            55
# 5991                          Molotov - Gimme Tha Power            55
# 6239      New Radicals - Crying Like A Church On Monday            55
# 7088  Ramones - I Don't Wanna Walk Around With You  ...            55
# 5291  Los Rodriguez - Milonga Del Marinero Y El Capitan            54
# 5481                    Mala Rodriguez - Tengo Un Trato            54
# 5731                           Megadeth - Kill The King            54
# 7121              Ray Barretto - A Deeper Shade Of Soul            54
# 7676                             Shotta - El Justiciero            54
# 9756                            Wolfmother - Love Train            54
# 5861  Michael Jackson - Happy (Love Theme From "Lady...            53
# 8139                      System of a Down - Lonely Day            53
# 725                               Audioslave - The Worm            52
# 2533            Devo - (I Can't Get Me No) Satisfaction            52
# 7234                   Ricardo Montaner - Déjame llorar            52
# 8577             The Four Seasons - Big Girls Don't Cry            52
# 9538                         Umphrey's McGee - 2nd Self            52
# 7232              Ricardo Arjona - Historia Del Portero            51
# 9286                          Three Days Grace - Scared            51
# 434                     Amparanoia - Don´t Leave Me Now            50
# 4587                       Juanes - No Creo En El Jamas            48
# 5048              Ladytron - Ghosts (Toxic Avenger Mix)            48
#
#       percentage
# 3812     0.41385
# 1112     0.35160
# 3288     0.34745
# 2724     0.32060
# 4911     0.30725
# 6473     0.29205
# 825      0.26925
# 1814     0.23975
# 9413     0.23790
# 1726     0.22740
# 4916     0.19880
# 9566     0.19735
# 5157     0.19395
# 9419     0.17890
# 3219     0.17630
# 5272     0.17555
# 1993     0.16860
# 4850     0.16090
# 1960     0.15695
# 397      0.15645
# 9445     0.15565
# 396      0.15400
# 5043     0.15240
# 5033     0.15160
# 5019     0.15045
# 4262     0.14880
# 9467     0.14435
# 7496     0.14330
# 6980     0.14195
# 2005     0.14145
# ...          ...
# 3166     0.00280
# 4080     0.00280
# 4178     0.00280
# 8467     0.00280
# 9285     0.00280
# 9343     0.00280
# 65       0.00275
# 2987     0.00275
# 5962     0.00275
# 5991     0.00275
# 6239     0.00275
# 7088     0.00275
# 5291     0.00270
# 5481     0.00270
# 5731     0.00270
# 7121     0.00270
# 7676     0.00270
# 9756     0.00270
# 5861     0.00265
# 8139     0.00265
# 725      0.00260
# 2533     0.00260
# 7234     0.00260
# 8577     0.00260
# 9538     0.00260
# 7232     0.00255
# 9286     0.00255
# 434      0.00250
# 4587     0.00240
# 5048     0.00240
#
# [9953 rows x 3 columns]

# %%
users = song_df['user_id'].unique()
len(users) ## return 365 unique users
songs = song_df['song'].unique()
len(songs) ## return 5151 unique songs
# Out:
# 9953

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data = train_test_split(song_df, test_size = 0.20, random_state=0)

# %%
from Recommenders import popularity_recommender_py

# %%
pm = popularity_recommender_py()
pm.create(train_data, 'user_id', 'song')
#user the popularity model to make some prediction
user_id = users[5]
listofrecommendedsongs = pm.recommend(user_id).to_json(orient='split')

# %%
# from bottle import * 
# @get('/listofsongs')
# def result_list():
#     return listofrecommendedsongs
# run(host="localhost", port="8080")
# Out:
# Bottle v0.12.16 server starting up (using WSGIRefServer())...
# Listening on http://localhost:8080/
# Hit Ctrl-C to quit.
